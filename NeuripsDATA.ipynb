# %%
# Core analysis packages
import numpy as np
import os, sys
import pandas as pd
from scipy import stats
from scipy.special import comb
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats import anova
# from patsy import dmatrices
import bff
import pingouin as pg

# Plotting packages
import matplotlib.pyplot as plt
plt.rcdefaults()
import matplotlib.colors as colors
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.cm as cmx
import pylab

import seaborn as sns 
sns.set(style="ticks", color_codes=True)
sns.set_style("white")
sns.set_style({'xtick.bottom': True, 'ytick.left': True})
colorref = ["gray", "royalblue", "crimson", "goldenrod", "mediumorchid", "seagreen"]

# iPython magic commands
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# %autosave 30

SMALL_SIZE = 12
MEDIUM_SIZE = 12
BIG_SIZE = 14

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIG_SIZE)  # fontsize of the figure title
cust_palette = sns.color_palette("Paired")[6:10]
cust_palette = [cust_palette[i] for i in [1,0,3,2]]
# Out:
# C:\Users\t-mvlasceanu\Miniconda3\envs\research\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.11, the latest is 0.3.12.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# Autosaving every 30 seconds

# %% [markdown]
# ### Scrape NeurIPS proceedings metadata

# %%
import numpy as np
from numpy import genfromtxt
import pandas as pd
from scipy import sparse
from scipy.cluster import hierarchy
from scipy.spatial import distance

import networkx as nx

from bs4 import BeautifulSoup
import urllib.request
import re, json, requests, itertools
from tqdm.notebook import tqdm

home = "https://proceedings.neurips.cc"
years = ["/paper/2015", "/paper/2016", "/paper/2017", "/paper/2018", "/paper/2019"]
# EDIT THE FOLLOWING LINE TO CHANGE WHICH YEAR'S DATA IS COLLECTED:
url = home+years[-5]

page = urllib.request.urlopen(url)
soup = BeautifulSoup(page.read(),"html.parser")
papers = soup.findAll("a", href=True)[3:-1]

# Extra annotations
conf = "neurips"
year = url[-4:]

# %% [markdown]
# ### Create dataframe using scraped data

# %%
df = pd.DataFrame(columns=["paper_id", "given_name", "family_name", "institution", "email"])

author_emails = []
# author_institutions = []

for paper in tqdm(papers):
    papermetaurl = url + "/file/" + paper["href"].split("/")[-1][:-13] + "Metadata.json"
    # requests approach: given that the output is a json, parse it directly (faster but not error-proof)
    rsp = requests.get(papermetaurl)
    d = rsp.json()
    # HTTP-generic BS4 approach: (more intensive)
#     metapage = urllib.request.urlopen(papermetaurl)
#     metasoup = BeautifulSoup(metapage.read(),"html.parser")
#     d = json.loads(metasoup.text)
    # Retrieve basic author block: names and affiliations + paperID for grouping
    authorblock = pd.DataFrame(d["authors"])
    authorblock.insert(0, "paper_id", d["sourceid"])
    authorblock.insert(1, "title", d["title"])
    # Retrieve author emails (if possible)
    try:
        fulltext = d["full_text"]
        stop = re.search(r"Abstract", fulltext).start(0)
        raw = re.sub(r"\n", " ", fulltext[:stop])
        raw = re.sub(r"({|})", "", raw)
        raw = re.sub(r", ", ",", raw)
        emails = re.findall(r"[\w][\w,\.-]+@[\w\.-]+", raw)
        # Additionally attempt to unpack grouped emails of the form {author1, author2, author3}@the.same.org.edu
        parsed_emails = []
        for email in emails:
            splitemail = email.split(",")
            if len(splitemail) > 1: # only true if there actually was a comma
                lastemail, commondomain = splitemail[-1].split("@")
                splitemail = [s+"@"+commondomain for s in splitemail[:-1]] + [splitemail[-1]]
            parsed_emails.append(splitemail)
        emails = list(itertools.chain(*parsed_emails))        
        # If the number of emails matches the number of authors, SUCCESS & include in data
        if len(authorblock) == len(emails):
            authorblock.insert(4, "email", emails)
    except:
        # The full-text is not always present in the metadata; just keep going
        pass

    df = df.append(authorblock)
df = df.reset_index()
df.insert(0, "year", year)
df.insert(0, "conference", conf)
# Out:
#   0%|          | 0/403 [00:00<?, ?it/s]

# %% [markdown]
# ### Construct organization variable from email domains

# %%
badtails = [
    "com", "edu", "org", "net", "ai", "io", "gov", "co", 
    "ac", "uk", "sg", "cn", "fr", "de", "ch", "cz", "ca", "hk", "tw", "il", "au", "dk", "pl", "it", "jp", "be", "kr", "ru", "uy", "qa", "br", "vn", "sa", "se", 
]

# test = "maddie@eecs.berkeley.ac.uk" # This should work: "berkeley"
# test = "maddie@google" # This shouldn't

def extract_org(email):
    try:
        (user, domain) = email.split("@")
        # Get CORE domain == org, s.t. eecs.berkeley.edu and berkeley.edu map to the same organization
        subdomains = domain.split(".")
        subdomains.pop()
        while subdomains[-1] in badtails: # Until the subdomain is not a country code or etc.
            subdomains.pop()
        return subdomains[-1]
    except:
        return np.nan
    
org = df["email"].apply(extract_org)
df.insert(6, "org", org)

# %%
df.head(20)
# Out:
#    conference  year  index paper_id   given_name        family_name  \
# 0     neurips  2015      0      550        Zheng                 Qu
# 1     neurips  2015      1      550        Peter          Richtarik
# 2     neurips  2015      2      550         Tong              Zhang
# 3     neurips  2015      0     1559         Arya           Mazumdar
# 4     neurips  2015      1     1559  Ankit Singh              Rawat
# 5     neurips  2015      0      890         Aviv              Tamar
# 6     neurips  2015      1      890       Yinlam               Chow
# 7     neurips  2015      2      890     Mohammad        Ghavamzadeh
# 8     neurips  2015      3      890         Shie             Mannor
# 9     neurips  2015      0      134       Miguel  Carreira-Perpinan
# 10    neurips  2015      1      134          Max         Vladymyrov
# 11    neurips  2015      0      245         Tian                Lin
# 12    neurips  2015      1      245         Jian                 Li
# 13    neurips  2015      2      245          Wei               Chen
# 14    neurips  2015      0      841         Qing                Sun
# 15    neurips  2015      1      841        Dhruv              Batra
# 16    neurips  2015      0       27      Huitong                Qiu
# 17    neurips  2015      1       27         Fang                Han
# 18    neurips  2015      2       27          Han                Liu
# 19    neurips  2015      3       27        Brian              Caffo
#
#           org                             institution  \
# 0         hku                 University of Hong Kong
# 1          ed                 University of Edinburgh
# 2     rutgers                                 Rutgers
# 3         umn  University of Minnesota -- Twin Cities
# 4         cmu              Carnegie Mellon University
# 5    berkeley                                Technion
# 6       inria                                Stanford
# 7    stanford                  Adobe Research & INRIA
# 8    technion                                Technion
# 9         NaN                               UC Merced
# 10        NaN                                   Yahoo
# 11      gmail                     Tsinghua University
# 12      gmail                     Tsinghua University
# 13  microsoft                           Microsoft.com
# 14        NaN                           Virginia Tech
# 15        NaN                           Virginia Tech
# 16        jhu                Johns Hopkins University
# 17        jhu                Johns Hopkins University
# 18      jhsph                    Princeton University
# 19  princeton                                    None
#
#                             email  \
# 0            zhengqu@maths.hku.hk
# 1        peter.richtarik@ed.ac.uk
# 2         tzhang@stat.rutgers.edu
# 3                    arya@umn.edu
# 4          asrawat@andrew.cmu.edu
# 5              avivt@berkeley.edu
# 6   mohammad.ghavamzadeh@inria.fr
# 7              ychow@stanford.edu
# 8          shie@ee.technion.ac.il
# 9                             NaN
# 10                            NaN
# 11            lintian06@gmail.com
# 12             lapordge@gmail.com
# 13             weic@microsoft.com
# 14                            NaN
# 15                            NaN
# 16                  hqiu7@jhu.edu
# 17                   fhan@jhu.edu
# 18               bcaffo@jhsph.edu
# 19           hanliu@princeton.edu
#
#                                                 title
# 0   Quartz: Randomized Dual Coordinate Ascent with...
# 1   Quartz: Randomized Dual Coordinate Ascent with...
# 2   Quartz: Randomized Dual Coordinate Ascent with...
# 3      Associative Memory via a Sparse Recovery Model
# 4      Associative Memory via a Sparse Recovery Model
# 5          Policy Gradient for Coherent Risk Measures
# 6          Policy Gradient for Coherent Risk Measures
# 7          Policy Gradient for Coherent Risk Measures
# 8          Policy Gradient for Coherent Risk Measures
# 9   A fast, universal algorithm to learn parametri...
# 10  A fast, universal algorithm to learn parametri...
# 11  Stochastic Online Greedy Learning with Semi-ba...
# 12  Stochastic Online Greedy Learning with Semi-ba...
# 13  Stochastic Online Greedy Learning with Semi-ba...
# 14  SubmodBoxes: Near-Optimal Search for a Set of ...
# 15  SubmodBoxes: Near-Optimal Search for a Set of ...
# 16                      Robust Portfolio Optimization
# 17                      Robust Portfolio Optimization
# 18                      Robust Portfolio Optimization
# 19                      Robust Portfolio Optimization

# %%
with open("./data/"+conf+"-"+year+"-titled.csv", "w", newline="", errors="ignore") as f:
    df.to_csv(path_or_buf=f, index=False, encoding="utf-8", errors="ignore")

# %% [markdown]
# **STOP**
#
# ---
#
# Some unit tests / debug / deprecated code:

# %% [markdown]
# ### Upload the compiled dataset containing all scraped years

# %%
# Load file (from same directory as the notebook)
df = pd.read_excel(os.path.expanduser("neurips-2015-19.xlsx"))
df.head()
# Out:
#   conference  year  index  paper_id   given_name family_name      org  \
# 0    neurips  2015      0       550        Zheng          Qu      hku
# 1    neurips  2015      1       550        Peter   Richtarik       ed
# 2    neurips  2015      2       550         Tong       Zhang  rutgers
# 3    neurips  2015      0      1559         Arya    Mazumdar      umn
# 4    neurips  2015      1      1559  Ankit Singh       Rawat      cmu
#
#                               institution                     email
# 0                 University of Hong Kong      zhengqu@maths.hku.hk
# 1                 University of Edinburgh  peter.richtarik@ed.ac.uk
# 2                                 Rutgers   tzhang@stat.rutgers.edu
# 3  University of Minnesota -- Twin Cities              arya@umn.edu
# 4              Carnegie Mellon University    asrawat@andrew.cmu.edu
